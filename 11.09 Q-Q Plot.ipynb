# %%
import numpy as np
import pylab
import scipy.stats as stats

#N(0,1)

std_normal=np.random.normal(loc=0,scale=1,size=1000)


#0 to 100 percentiles of std_normal

for i in range(0,101):
    print(i,np.percentile(std_normal,i))
# Out:
# 0 -2.9952610680366383
# 1 -2.215469059008231
# 2 -1.971601703335203
# 3 -1.7972385160497226
# 4 -1.6665071828375406
# 5 -1.5898441425377345
# 6 -1.505602161540575
# 7 -1.4368793612016553
# 8 -1.3509309348791334
# 9 -1.3146415542750471
# 10 -1.2778592036018617
# 11 -1.1941494140738056
# 12 -1.1602850388380517
# 13 -1.1032892327998687
# 14 -1.0487690049582505
# 15 -0.9973844286702211
# 16 -0.9479772775309734
# 17 -0.906237708537986
# 18 -0.8531051345026851
# 19 -0.8102959933589685
# 20 -0.7805583712213857
# 21 -0.7473104872339857
# 22 -0.6902052711747048
# 23 -0.6709167847663188
# 24 -0.6350664706051228
# 25 -0.6142381375995567
# 26 -0.5907208364617018
# 27 -0.5660258910075502
# 28 -0.5385238353475363
# 29 -0.502579218073169
# 30 -0.479710165450763
# 31 -0.45135123571845115
# 32 -0.4256076750884801
# 33 -0.4055378691306984
# 34 -0.3728771432308228
# 35 -0.3327832860427502
# 36 -0.32157471409060706
# 37 -0.30819561909779647
# 38 -0.27448647069492416
# 39 -0.25565975066698
# 40 -0.2336466247831685
# 41 -0.21296032987418237
# 42 -0.17858333252377706
# 43 -0.15786480517793958
# 44 -0.1375653766044248
# 45 -0.10274323619325433
# 46 -0.08153385662548439
# 47 -0.07258429994774171
# 48 -0.03676317935424117
# 49 -0.024618419263446625
# 50 -0.005009850082251883
# 51 0.012629472574344078
# 52 0.03791161125602171
# 53 0.06347133986943872
# 54 0.0878964848761052
# 55 0.1205980031619014
# 56 0.1411250744112777
# 57 0.16882393314567337
# 58 0.19607406760604112
# 59 0.23608441143985687
# 60 0.24773613544672327
# 61 0.26683019347941195
# 62 0.2913369913264449
# 63 0.3217664451059352
# 64 0.34309782154735546
# 65 0.35268994483958443
# 66 0.39034362977346293
# 67 0.4073492943632756
# 68 0.43274387206902887
# 69 0.45877378246339
# 70 0.49799002258216696
# 71 0.5318679888316526
# 72 0.5548358135526199
# 73 0.5719878427156547
# 74 0.5953606669771094
# 75 0.6199364052546249
# 76 0.6380409050642696
# 77 0.6604005970350442
# 78 0.6891724594845072
# 79 0.72494289685259
# 80 0.748094947182292
# 81 0.7948832096321642
# 82 0.8206842117731092
# 83 0.8554922047995097
# 84 0.9354108512210194
# 85 0.9842200328256574
# 86 1.0130995091233614
# 87 1.0695233544266294
# 88 1.107655673584412
# 89 1.1399832418838423
# 90 1.1885183922229015
# 91 1.236307596063133
# 92 1.2718314436657185
# 93 1.338309234797223
# 94 1.405237465809384
# 95 1.4758683260172825
# 96 1.566958914958408
# 97 1.7345251383786529
# 98 1.8820575833390598
# 99 2.2957366031455226
# 100 3.099336730140633

# %%
#Generate 100 samples from N(20,5)

measurements=np.random.normal(loc=20,scale=5,size=900000)
stats.probplot(measurements,dist='norm',plot=pylab)
pylab.show()

# %%
measurements=np.random.uniform(low=-1,high=1,size=100)
stats.probplot(measurements,dist='norm',plot=pylab)
pylab.show()
